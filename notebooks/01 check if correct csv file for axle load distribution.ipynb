# %% [markdown]
# Making sure the csv file i had available made the same results as those in the report.
#
# All looks good.

# %%
import pandas as pd
from source.config import INTERIM_DATA_DIR

df_single = pd.read_csv(INTERIM_DATA_DIR / 'Enkeltaksler axle load distribution.csv')
df_boggi = pd.read_csv(INTERIM_DATA_DIR / 'Boggiaksler axle load distribution.csv')
df_triple = pd.read_csv(INTERIM_DATA_DIR / 'Trippelaksler axle load distribution.csv')

# %%
df_single.head()
# Out:
#       Sted  0-1 tonn   1-2 tonn   2-3 tonn  3-4 tonn   4-5 tonn   5-6 tonn  \
# 0  Skibotn  1.439005  28.327455  27.632309  4.705301   3.197315   3.875393
# 1   Verdal  0.852888  13.087178   7.992493  8.100173  10.662611  15.190969
# 2  Ånestad  0.860508  24.888510   8.412659  3.345539   5.252465   9.899376
# 3   Øysand  0.788131  16.392873  10.257029  6.230543   9.439467  14.821168
# 4    Total  0.915217  19.128456  12.065268  5.848051   7.948798  12.288460
#
#     6-7 tonn   7-8 tonn   8-9 tonn  ...  20-21 tonn  21-22 tonn  22-23 tonn  \
# 0   5.454138   6.694733   6.518369  ...    0.005689    0.004267    0.002133
# 1  16.824539  16.063733   7.226906  ...    0.000000    0.000000    0.000000
# 2  12.549661  14.036944  10.554166  ...    0.001132    0.000283    0.000283
# 3  13.891543  11.474814   7.720972  ...    0.000739    0.000369    0.000000
# 4  12.979834  12.225884   7.974013  ...    0.001410    0.000868    0.000380
#
# ...

# %%
df_boggi.head()
# Out:
#       Sted  0-1 tonn  1-2 tonn  2-3 tonn  3-4 tonn  4-5 tonn  5-6 tonn  \
# 0  Skibotn  0.692748  2.333930  4.035569  2.127365  1.762098  2.112250
# 1   Verdal  0.507744  4.276518  1.929709  1.186860  3.408326  2.334771
# 2  Ånestad  2.253735  3.653670  1.515477  0.867235  1.234684  2.187903
# 3   Øysand  1.549090  4.161096  1.879217  2.267764  3.275006  3.614935
# 4    Total  1.372725  3.833960  2.078063  1.671673  2.626480  2.794288
#
#    6-7 tonn  7-8 tonn  8-9 tonn  ...  20-21 tonn  21-22 tonn  22-23 tonn  \
# 0  3.412097  4.248432  4.769882  ...    4.281180    3.535532    2.749578
# 1  4.510208  6.893133  6.145327  ...    0.647957    0.269805    0.116137
# 2  2.971168  3.388328  3.882067  ...    3.746373    1.592729    0.425220
# 3  4.966419  6.000322  5.711754  ...    1.951359    1.577319    1.040176
# 4  4.190071  5.356880  5.253921  ...    2.380693    1.534289    0.901967
#
#    23-24 tonn  24-25 tonn  25-26 tonn  26-27 tonn  27-28 tonn  28-29 tonn  \
# ...

# %%
df_triple.head()
# Out:
#       Sted  0-1 tonn  1-2 tonn  2-3 tonn  3-4 tonn  4-5 tonn  5-6 tonn  \
# 0  Skibotn  0.037533  0.207538  0.375334  0.699887  0.929503  1.318084
# 1   Verdal  0.031148  0.062296  0.109017  0.062296  0.077869  0.031148
# 2  Ånestad  0.046564  0.399122  0.224506  0.264418  0.201224  0.891372
# 3   Øysand  0.023315  0.156547  0.163208  0.179862  1.435566  3.394065
# 4    Total  0.038063  0.271377  0.254460  0.376404  0.689368  1.518302
#
#    6-7 tonn  7-8 tonn  8-9 tonn  ...  20-21 tonn  21-22 tonn  22-23 tonn  \
# 0  2.199015  3.570088  4.254521  ...    3.706975    4.002826    4.300885
# 1  0.155739  0.124591  0.622956  ...    7.958262   11.291076   15.838654
# 2  2.569347  4.320495  4.644781  ...    3.924699    4.337125    4.766181
# 3  3.897012  5.469140  8.117110  ...    5.209340    5.735603    5.589048
# 4  2.622842  4.134096  5.072990  ...    4.309610    4.841086    5.292911
#
#    23-24 tonn  24-25 tonn  25-26 tonn  26-27 tonn  27-28 tonn  28-29 tonn  \
# ...
